# %% [markdown]
# # 1. 구글 코랩 AI
#
# 오늘은 구글 코랩 AI 사용법에 대해서 알아볼거예요.
#  * '#'은 대제목
#  * '*'는 순서가 없는 구분자

# %% [markdown]
# ### 5*5 빙고게임

# %%
import random

# Create a list of numbers from 1 to 25
numbers = list(range(1, 26))

# Create a list of 5 empty lists to represent the rows of the bingo board
board = [[] for _ in range(5)]

# Fill each row of the board with 5 random numbers
for row in board:
  for _ in range(5):
    number = random.choice(numbers)
    row.append(number)
    numbers.remove(number)

# Print the bingo board
for row in board:
  print(' '.join(map(str, row)))
# Out:
# 6 19 3 15 2
# 17 5 7 22 11
# 16 8 14 12 23
# 18 4 24 20 21
# 13 10 25 1 9

# %% [markdown]
# ### 데이터셋 생성 및 확인

# %%
# prompt: 샘플 데이터 프레임 하나 생성해줘

import pandas as pd
df = pd.DataFrame({
    "Name": ["Alice", "Bob", "Carol", "Dave", "Eve"],
    "Age": [20, 25, 30, 35, 40]
})

# %%
df
# Out:
#     Name  Age
# 0  Alice   20
# 1    Bob   25
# 2  Carol   30
# 3   Dave   35
# 4    Eve   40

# %% [markdown]
# ### 생성한 데이터셋으로 막대그래프 생성

# %%
# prompt: df DataFrame 사용: 해당 데이터셋으로 막대그래프를 그리고싶어

import matplotlib.pyplot as plt

df.plot(x='Name', y='Age', kind='bar')
plt.show()
